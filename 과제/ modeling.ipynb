# %% [markdown]
# <a href="https://colab.research.google.com/github/amthreeh/ComputerVision_Seminar/blob/main/%EA%B3%BC%EC%A0%9C/%20modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CV_seminar_project
# Out:
# /content/drive/MyDrive/CV_seminar_project

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/CV_seminar_project'

# %%
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu' # device 배정
torch.manual_seed(42)
if device == 'cuda':
  torch.cuda.manual_seed_all(42)
device
# Out:
# 'cuda'

# %% [markdown]
# # 1. 데이터 셋 준비하기

# %%
import torch.nn as nn

# 하이퍼 파라미터
batch_size = 8
lr = 0.0001
epochs = 100
optimizer_name = 'adam'
model_name = 'resnet50'
criterion = nn.CrossEntropyLoss().to(device) # cost function

# %%
from dataset import Custom_dataset as C
from torch.utils.data import Dataset, DataLoader
import cv2
import os 
import torch
import torchvision
from torchvision import transforms # 이미지 데이터 augmentation
import glob
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2 # albumentations 텐서화 함수

root_path = '/content/drive/MyDrive/CV_seminar_project'

train_transforms = A.Compose([
    A.Resize(224,224),
    A.Transpose(p=0.5),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.ShiftScaleRotate(p=0.5),
    A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=20, val_shift_limit=20, p=0.5),
    A.RandomBrightnessContrast(brightness_limit=(-0.1,0.1), contrast_limit=(-0.1, 0.1), p=0.5),
    A.ChannelShuffle(),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0, always_apply=False, p=1.0), # 이미지넷 데이터셋 통계값으로 Normalize
    A.CoarseDropout(p=0.5),
    ToTensorV2()
])

test_transforms = A.Compose([
    A.Resize(224,224),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0, always_apply=False, p=1.0), # 텐서타입은 안해줌
    ToTensorV2() # Normalize를 먼저하고 tensor화를 진행해야한다.
])

### Pytorch 데이터 클래스 생성
train_class = C(root_path=root_path, mode='train', transforms=train_transforms)
valid_class = C(root_path=root_path, mode='valid', transforms=test_transforms)
test_class = C(root_path=root_path, mode='test', transforms=test_transforms)

### Pytorch BatchLoader 생성 (학습에 이용할 최종 dataloader)
from torch.utils.data import DataLoader as DataLoader

train_loader = DataLoader(train_class, batch_size=batch_size, shuffle = True, num_workers=0)
valid_loader = DataLoader(valid_class, batch_size=batch_size, shuffle = False, num_workers=0)
test_loader = DataLoader(test_class, batch_size=batch_size, shuffle = False, num_workers=0)

# %% [markdown]
# # 2. 모델 불러오기

# %%
from torchvision import models # 모델 라이브러리 함수

resnet_50 = models.resnet50(pretrained=True).to(device) # 선행학습 여부

# finetuning
import torch.nn as nn # 파이토치 뉴럴네트워크 layer 라이브러리
resnet_50.fc = nn.Linear(resnet_50.fc.in_features, 3).to(device)
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %%
from torchsummary import summary # 모델 아키텍쳐 확인하는 함수

summary(resnet_50, input_size = (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        Bottleneck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        Bottleneck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        Bottleneck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        Bottleneck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        Bottleneck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        Bottleneck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        Bottleneck-78          [-1, 512, 28, 28]               0
#            Conv2d-79          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-80          [-1, 256, 28, 28]             512
#              ReLU-81          [-1, 256, 28, 28]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#            Conv2d-85         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-86         [-1, 1024, 14, 14]           2,048
#            Conv2d-87         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-88         [-1, 1024, 14, 14]           2,048
#              ReLU-89         [-1, 1024, 14, 14]               0
#        Bottleneck-90         [-1, 1024, 14, 14]               0
#            Conv2d-91          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-92          [-1, 256, 14, 14]             512
#              ReLU-93          [-1, 256, 14, 14]               0
#            Conv2d-94          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-95          [-1, 256, 14, 14]             512
#              ReLU-96          [-1, 256, 14, 14]               0
#            Conv2d-97         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-98         [-1, 1024, 14, 14]           2,048
#              ReLU-99         [-1, 1024, 14, 14]               0
#       Bottleneck-100         [-1, 1024, 14, 14]               0
#           Conv2d-101          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-102          [-1, 256, 14, 14]             512
#             ReLU-103          [-1, 256, 14, 14]               0
#           Conv2d-104          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-105          [-1, 256, 14, 14]             512
#             ReLU-106          [-1, 256, 14, 14]               0
#           Conv2d-107         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-108         [-1, 1024, 14, 14]           2,048
#             ReLU-109         [-1, 1024, 14, 14]               0
#       Bottleneck-110         [-1, 1024, 14, 14]               0
#           Conv2d-111          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-112          [-1, 256, 14, 14]             512
#             ReLU-113          [-1, 256, 14, 14]               0
#           Conv2d-114          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-115          [-1, 256, 14, 14]             512
#             ReLU-116          [-1, 256, 14, 14]               0
#           Conv2d-117         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-118         [-1, 1024, 14, 14]           2,048
#             ReLU-119         [-1, 1024, 14, 14]               0
#       Bottleneck-120         [-1, 1024, 14, 14]               0
#           Conv2d-121          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-122          [-1, 256, 14, 14]             512
#             ReLU-123          [-1, 256, 14, 14]               0
#           Conv2d-124          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-125          [-1, 256, 14, 14]             512
#             ReLU-126          [-1, 256, 14, 14]               0
#           Conv2d-127         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-128         [-1, 1024, 14, 14]           2,048
#             ReLU-129         [-1, 1024, 14, 14]               0
#       Bottleneck-130         [-1, 1024, 14, 14]               0
#           Conv2d-131          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-132          [-1, 256, 14, 14]             512
#             ReLU-133          [-1, 256, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#           Conv2d-137         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-138         [-1, 1024, 14, 14]           2,048
#             ReLU-139         [-1, 1024, 14, 14]               0
#       Bottleneck-140         [-1, 1024, 14, 14]               0
#           Conv2d-141          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-142          [-1, 512, 14, 14]           1,024
#             ReLU-143          [-1, 512, 14, 14]               0
#           Conv2d-144            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-145            [-1, 512, 7, 7]           1,024
#             ReLU-146            [-1, 512, 7, 7]               0
#           Conv2d-147           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 7, 7]           4,096
#           Conv2d-149           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 7, 7]           4,096
#             ReLU-151           [-1, 2048, 7, 7]               0
#       Bottleneck-152           [-1, 2048, 7, 7]               0
#           Conv2d-153            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-154            [-1, 512, 7, 7]           1,024
#             ReLU-155            [-1, 512, 7, 7]               0
#           Conv2d-156            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-157            [-1, 512, 7, 7]           1,024
#             ReLU-158            [-1, 512, 7, 7]               0
#           Conv2d-159           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 7, 7]           4,096
#             ReLU-161           [-1, 2048, 7, 7]               0
#       Bottleneck-162           [-1, 2048, 7, 7]               0
#           Conv2d-163            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-164            [-1, 512, 7, 7]           1,024
#             ReLU-165            [-1, 512, 7, 7]               0
#           Conv2d-166            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-167            [-1, 512, 7, 7]           1,024
#             ReLU-168            [-1, 512, 7, 7]               0
#           Conv2d-169           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 7, 7]           4,096
#             ReLU-171           [-1, 2048, 7, 7]               0
#       Bottleneck-172           [-1, 2048, 7, 7]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                    [-1, 3]           6,147
# ================================================================
# Total params: 23,514,179
# Trainable params: 23,514,179
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 286.55
# Params size (MB): 89.70
# Estimated Total Size (MB): 376.82
# ----------------------------------------------------------------

# %%
optimizer = torch.optim.Adam(resnet_50.parameters(), lr = lr, weight_decay = 1e-8)

# %% [markdown]
# # 3. 모델 학습시키기

# %% [markdown]
# 현재(2019년) 시점에서는 모델링 시 training과 inference시에 다르게 동작하는 layer들이 존재한다. 예를 들면, Dropout layer는 학습시에는 동작해야하지만, inference시에는 동작하지 않는 것과 같은 예시를 들 수 있다. BatchNorm같은 경우도 마찬가지다.
#
# 사실상 model.eval()는 이런 layer들의 동작을 inference(eval) mode로 바꿔준다는 목적으로 사용된다. 따라서, 우리가 보통 원하는 모델의 동작을 위해서는 위의 두 가지를 모두 사용해야하는 것이 맞다.

# %% [markdown]
# #모델 저장하기:
# - 딕셔너리 형식의 pth 확장자로 저장이 된다.
# - validation set의 성능이 여태까지 epoch의 성능에서 best일때의 모델의 가중치를 저장한다.

# %%
import numpy as np

train_acc_lst = []
train_loss_lst = []

test_acc_lst = []
test_loss_lst = []

save_dir = '/content/drive/MyDrive/CV_seminar_project'
model_name = 'resnet50'

for epoch in range(1, epochs):
  running_loss = 0.0
  test_running_loss = 0.0

  total = 0
  correct = 0
  
  train_acc = 0
  test_acc = 0

  resnet_50.train()
  for i, (train_img, train_label) in enumerate(train_loader):
    # gpu에 할당
    train_img = train_img.to(device)
    train_label = train_label.to(device)
    optimizer.zero_grad( set_to_none = True ) # 계산했던 가중치 초기화

    output = resnet_50(train_img) # 모델에 입력
    loss = criterion(output, train_label)
    loss.backward() # 미분
    optimizer.step() # 학습

    # loss & acc
    running_loss += loss.item()
    _, predictions = torch.max(output.data ,dim = 1 )
    
    total += train_label.size(0)
    correct += (predictions == train_label).sum().item()
    train_acc += 100 * (correct/total)

  running_loss = round(running_loss/(i+1), 3) # 소수점 반올림
  train_acc = round(train_acc/(i+1), 3)
  
  print(f'Trainset{epoch}/{epochs} Loss : {running_loss}, Accuracy : {train_acc}%')
  train_acc_lst.append(train_acc)
  train_loss_lst.append(running_loss)


  total = 0
  correct = 0
  resnet_50.eval()
  with torch.no_grad(): #계속 gradient 계산을 하는데 그걸 멈출 수 있음
    for ii, (valid_img, valid_label) in enumerate(valid_loader):
          # gpu에 할당
      valid_img = valid_img.to(device)
      valid_label = valid_label.to(device)

      output = resnet_50(valid_img) # 모델에 입력
      loss = criterion(output, valid_label)

      # loss & acc
      test_running_loss += loss.item()
      _, predictions = torch.max(output.data ,dim = 1 )
      
      total += valid_label.size(0)
      correct += (predictions == valid_label).sum().item()
      test_acc += 100 * (correct/total)

  test_running_loss = round(test_running_loss/(ii+1), 3) # 소수점 반올림
  test_acc = round(test_acc/(ii+1), 3)
  print(f'Validset{epoch}/{epochs} Loss : {test_running_loss}, Accuracy : {test_acc}% \n')
  test_acc_lst.append(test_acc)
  test_loss_lst.append(test_running_loss)

  if np.max(test_acc_lst) <= test_acc:  #현재 에포크의 test_acc가 가장 좋은 성능이라면,
    weights = resnet_50.state_dict()  #지금 모델의 가중치를 저장한다.
    check_point = {
        'net' : weights,
        'epoch' : epoch,

        'train_loss' : running_loss,
        'test_loss' : test_running_loss,

        'train_acc' : train_acc,
        'test_acc' : test_acc
    }
  
  torch.save(check_point, save_dir+f'/{model_name}.pth')
# Out:
# Trainset1/100 Loss : 0.818, Accuracy : 52.967%
# Validset1/100 Loss : 0.713, Accuracy : 69.045%
#
# Trainset2/100 Loss : 0.69, Accuracy : 67.866%
# Validset2/100 Loss : 0.675, Accuracy : 65.062%
#
# Trainset3/100 Loss : 0.597, Accuracy : 76.549%
# Validset3/100 Loss : 0.475, Accuracy : 75.769%
#
# Trainset4/100 Loss : 0.581, Accuracy : 75.886%
# Validset4/100 Loss : 0.55, Accuracy : 80.337%
#
# Trainset5/100 Loss : 0.5, Accuracy : 77.879%
# Validset5/100 Loss : 0.429, Accuracy : 78.27%
#
# Trainset6/100 Loss : 0.448, Accuracy : 82.107%
# Validset6/100 Loss : 0.459, Accuracy : 82.201%
#
# Trainset7/100 Loss : 0.452, Accuracy : 83.333%
# Validset7/100 Loss : 0.514, Accuracy : 72.921%
#
# Trainset8/100 Loss : 0.428, Accuracy : 84.87%
# Validset8/100 Loss : 0.441, Accuracy : 73.276%
#
# Trainset9/100 Loss : 0.367, Accuracy : 87.068%
# Validset9/100 Loss : 0.514, Accuracy : 71.933%
#
# Trainset10/100 Loss : 0.415, Accuracy : 84.238%
# Validset10/100 Loss : 0.381, Accuracy : 81.037%
#
# Trainset11/100 Loss : 0.343, Accuracy : 88.977%
# Validset11/100 Loss : 0.401, Accuracy : 83.376%
#
# Trainset12/100 Loss : 0.358, Accuracy : 85.873%
# Validset12/100 Loss : 0.402, Accuracy : 80.196%
#
# Trainset13/100 Loss : 0.334, Accuracy : 89.001%
# Validset13/100 Loss : 0.316, Accuracy : 85.814%
#
# Trainset14/100 Loss : 0.307, Accuracy : 89.518%
# Validset14/100 Loss : 0.464, Accuracy : 72.274%
#
# Trainset15/100 Loss : 0.253, Accuracy : 89.996%
# Validset15/100 Loss : 0.436, Accuracy : 82.945%
#
# Trainset16/100 Loss : 0.359, Accuracy : 88.674%
# Validset16/100 Loss : 0.421, Accuracy : 82.584%
#
# Trainset17/100 Loss : 0.246, Accuracy : 91.901%
# Validset17/100 Loss : 0.43, Accuracy : 78.408%
#
# Trainset18/100 Loss : 0.284, Accuracy : 88.842%
# Validset18/100 Loss : 0.348, Accuracy : 75.203%
#
# Trainset19/100 Loss : 0.277, Accuracy : 92.406%
# Validset19/100 Loss : 0.481, Accuracy : 66.883%
#
# Trainset20/100 Loss : 0.326, Accuracy : 86.251%
# Validset20/100 Loss : 0.396, Accuracy : 84.874%
#
# Trainset21/100 Loss : 0.232, Accuracy : 91.09%
# Validset21/100 Loss : 0.337, Accuracy : 76.745%
#
# Trainset22/100 Loss : 0.215, Accuracy : 90.539%
# Validset22/100 Loss : 0.312, Accuracy : 85.322%
#
# Trainset23/100 Loss : 0.247, Accuracy : 91.75%
# Validset23/100 Loss : 0.439, Accuracy : 76.856%
#
# Trainset24/100 Loss : 0.244, Accuracy : 88.94%
# Validset24/100 Loss : 0.267, Accuracy : 84.29%
#
# Trainset25/100 Loss : 0.204, Accuracy : 92.319%
# Validset25/100 Loss : 0.325, Accuracy : 83.705%
#
# Trainset26/100 Loss : 0.242, Accuracy : 90.945%
# Validset26/100 Loss : 0.341, Accuracy : 84.983%
#
# Trainset27/100 Loss : 0.18, Accuracy : 93.146%
# Validset27/100 Loss : 0.335, Accuracy : 82.166%
#
# Trainset28/100 Loss : 0.226, Accuracy : 91.416%
# Validset28/100 Loss : 0.361, Accuracy : 86.326%
#
# Trainset29/100 Loss : 0.201, Accuracy : 92.831%
# Validset29/100 Loss : 0.372, Accuracy : 85.717%
#
# Trainset30/100 Loss : 0.213, Accuracy : 93.959%
# Validset30/100 Loss : 0.362, Accuracy : 80.061%
#
# Trainset31/100 Loss : 0.208, Accuracy : 89.292%
# Validset31/100 Loss : 0.383, Accuracy : 82.449%
#
# Trainset32/100 Loss : 0.157, Accuracy : 94.103%
# Validset32/100 Loss : 0.419, Accuracy : 72.59%
#
# Trainset33/100 Loss : 0.191, Accuracy : 95.066%
# Validset33/100 Loss : 0.355, Accuracy : 79.329%
#
# Trainset34/100 Loss : 0.196, Accuracy : 91.506%
# Validset34/100 Loss : 0.399, Accuracy : 82.174%
#
# Trainset35/100 Loss : 0.225, Accuracy : 91.835%
# Validset35/100 Loss : 0.299, Accuracy : 85.726%
#
# Trainset36/100 Loss : 0.202, Accuracy : 94.849%
# Validset36/100 Loss : 0.496, Accuracy : 78.495%
#
# Trainset37/100 Loss : 0.2, Accuracy : 92.257%
# Validset37/100 Loss : 0.326, Accuracy : 80.683%
#
# Trainset38/100 Loss : 0.212, Accuracy : 93.185%
# Validset38/100 Loss : 0.278, Accuracy : 84.63%
#
# Trainset39/100 Loss : 0.198, Accuracy : 92.961%
# Validset39/100 Loss : 0.268, Accuracy : 89.377%
#
# Trainset40/100 Loss : 0.128, Accuracy : 96.865%
# Validset40/100 Loss : 0.35, Accuracy : 92.824%
#
# Trainset41/100 Loss : 0.143, Accuracy : 96.821%
# Validset41/100 Loss : 0.578, Accuracy : 79.972%
#
# Trainset42/100 Loss : 0.151, Accuracy : 96.073%
# Validset42/100 Loss : 0.398, Accuracy : 82.544%
#
# Trainset43/100 Loss : 0.124, Accuracy : 95.367%
# Validset43/100 Loss : 0.435, Accuracy : 79.523%
#
# Trainset44/100 Loss : 0.197, Accuracy : 94.759%
# Validset44/100 Loss : 0.406, Accuracy : 78.912%
#
# Trainset45/100 Loss : 0.154, Accuracy : 92.828%
# Validset45/100 Loss : 0.237, Accuracy : 88.725%
#
# Trainset46/100 Loss : 0.13, Accuracy : 96.302%
# Validset46/100 Loss : 0.439, Accuracy : 71.38%
#
# Trainset47/100 Loss : 0.211, Accuracy : 94.285%
# Validset47/100 Loss : 0.324, Accuracy : 83.395%
#
# Trainset48/100 Loss : 0.122, Accuracy : 95.584%
# Validset48/100 Loss : 0.303, Accuracy : 80.469%
#
# Trainset49/100 Loss : 0.157, Accuracy : 94.482%
# Validset49/100 Loss : 0.281, Accuracy : 86.605%
#
# Trainset50/100 Loss : 0.157, Accuracy : 94.883%
# Validset50/100 Loss : 0.429, Accuracy : 75.473%
#
# Trainset51/100 Loss : 0.171, Accuracy : 94.193%
# Validset51/100 Loss : 0.336, Accuracy : 85.385%
#
# Trainset52/100 Loss : 0.123, Accuracy : 97.166%
# Validset52/100 Loss : 0.28, Accuracy : 87.282%
#
# Trainset53/100 Loss : 0.142, Accuracy : 94.028%
# Validset53/100 Loss : 0.438, Accuracy : 79.028%
#
# Trainset54/100 Loss : 0.114, Accuracy : 95.341%
# Validset54/100 Loss : 0.274, Accuracy : 90.316%
#
# Trainset55/100 Loss : 0.139, Accuracy : 96.525%
# Validset55/100 Loss : 0.308, Accuracy : 87.232%
#
# Trainset56/100 Loss : 0.131, Accuracy : 95.034%
# Validset56/100 Loss : 0.232, Accuracy : 91.665%
#
# Trainset57/100 Loss : 0.107, Accuracy : 97.333%
# Validset57/100 Loss : 0.354, Accuracy : 86.34%
#
# Trainset58/100 Loss : 0.088, Accuracy : 96.084%
# Validset58/100 Loss : 0.277, Accuracy : 86.086%
#
# Trainset59/100 Loss : 0.121, Accuracy : 95.651%
# Validset59/100 Loss : 0.26, Accuracy : 86.639%
#
# Trainset60/100 Loss : 0.109, Accuracy : 96.339%
# Validset60/100 Loss : 0.352, Accuracy : 79.038%
#
# Trainset61/100 Loss : 0.158, Accuracy : 95.009%
# Validset61/100 Loss : 0.249, Accuracy : 84.659%
#
# Trainset62/100 Loss : 0.139, Accuracy : 96.08%
# Validset62/100 Loss : 0.216, Accuracy : 93.737%
#
# Trainset63/100 Loss : 0.239, Accuracy : 91.527%
# Validset63/100 Loss : 0.216, Accuracy : 92.834%
#
# Trainset64/100 Loss : 0.138, Accuracy : 95.557%
# Validset64/100 Loss : 0.294, Accuracy : 84.153%
#
# Trainset65/100 Loss : 0.097, Accuracy : 96.514%
# Validset65/100 Loss : 0.303, Accuracy : 83.586%
#
# Trainset66/100 Loss : 0.096, Accuracy : 95.042%
# Validset66/100 Loss : 0.277, Accuracy : 87.382%
#
# Trainset67/100 Loss : 0.103, Accuracy : 97.625%
# Validset67/100 Loss : 0.231, Accuracy : 85.53%
#
# Trainset68/100 Loss : 0.103, Accuracy : 95.336%
# Validset68/100 Loss : 0.197, Accuracy : 88.803%
#
# Trainset69/100 Loss : 0.102, Accuracy : 97.678%
# Validset69/100 Loss : 0.352, Accuracy : 89.491%
#
# Trainset70/100 Loss : 0.111, Accuracy : 96.833%
# Validset70/100 Loss : 0.237, Accuracy : 89.423%
#
# Trainset71/100 Loss : 0.096, Accuracy : 97.368%
# Validset71/100 Loss : 0.415, Accuracy : 83.962%
#
# Trainset72/100 Loss : 0.173, Accuracy : 96.383%
# Validset72/100 Loss : 0.541, Accuracy : 73.399%
#
# Trainset73/100 Loss : 0.128, Accuracy : 95.473%
# Validset73/100 Loss : 0.307, Accuracy : 82.489%
#
# Trainset74/100 Loss : 0.098, Accuracy : 96.628%
# Validset74/100 Loss : 0.32, Accuracy : 84.993%
#
# Trainset75/100 Loss : 0.091, Accuracy : 97.795%
# Validset75/100 Loss : 0.283, Accuracy : 87.734%
#
# Trainset76/100 Loss : 0.113, Accuracy : 97.254%
# Validset76/100 Loss : 0.313, Accuracy : 81.955%
#
# Trainset77/100 Loss : 0.103, Accuracy : 95.562%
# Validset77/100 Loss : 0.431, Accuracy : 73.309%
#
# Trainset78/100 Loss : 0.069, Accuracy : 97.577%
# Validset78/100 Loss : 0.287, Accuracy : 89.65%
#
# Trainset79/100 Loss : 0.098, Accuracy : 97.765%
# Validset79/100 Loss : 0.346, Accuracy : 84.297%
#
# Trainset80/100 Loss : 0.096, Accuracy : 96.407%
# Validset80/100 Loss : 0.503, Accuracy : 71.816%
#
# Trainset81/100 Loss : 0.09, Accuracy : 97.221%
# Validset81/100 Loss : 0.308, Accuracy : 90.156%
#
# Trainset82/100 Loss : 0.139, Accuracy : 96.561%
# Validset82/100 Loss : 0.304, Accuracy : 87.662%
#
# Trainset83/100 Loss : 0.133, Accuracy : 93.967%
# Validset83/100 Loss : 0.34, Accuracy : 86.966%
#
# Trainset84/100 Loss : 0.093, Accuracy : 97.223%
# Validset84/100 Loss : 0.388, Accuracy : 82.924%
#
# Trainset85/100 Loss : 0.076, Accuracy : 97.942%
# Validset85/100 Loss : 0.382, Accuracy : 77.889%
#
# Trainset86/100 Loss : 0.089, Accuracy : 97.882%
# Validset86/100 Loss : 0.431, Accuracy : 78.34%
#
# Trainset87/100 Loss : 0.098, Accuracy : 96.363%
# Validset87/100 Loss : 0.41, Accuracy : 80.841%
#
# Trainset88/100 Loss : 0.066, Accuracy : 96.812%
# Validset88/100 Loss : 0.342, Accuracy : 89.729%
#
# Trainset89/100 Loss : 0.068, Accuracy : 97.984%
# Validset89/100 Loss : 0.558, Accuracy : 73.113%
#
# Trainset90/100 Loss : 0.053, Accuracy : 98.048%
# Validset90/100 Loss : 0.417, Accuracy : 78.209%
#
# Trainset91/100 Loss : 0.099, Accuracy : 97.99%
# Validset91/100 Loss : 0.513, Accuracy : 80.508%
#
# Trainset92/100 Loss : 0.085, Accuracy : 96.109%
# Validset92/100 Loss : 0.334, Accuracy : 86.467%
#
# Trainset93/100 Loss : 0.134, Accuracy : 95.42%
# Validset93/100 Loss : 0.427, Accuracy : 79.41%
#
# Trainset94/100 Loss : 0.119, Accuracy : 96.389%
# Validset94/100 Loss : 0.42, Accuracy : 76.151%
#
# Trainset95/100 Loss : 0.126, Accuracy : 97.657%
# Validset95/100 Loss : 0.413, Accuracy : 81.708%
#
# Trainset96/100 Loss : 0.09, Accuracy : 97.031%
# Validset96/100 Loss : 0.235, Accuracy : 88.873%
#
# Trainset97/100 Loss : 0.046, Accuracy : 98.235%
# Validset97/100 Loss : 0.299, Accuracy : 86.759%
#
# Trainset98/100 Loss : 0.089, Accuracy : 96.475%
# Validset98/100 Loss : 0.277, Accuracy : 89.462%
#
# Trainset99/100 Loss : 0.074, Accuracy : 97.231%
# Validset99/100 Loss : 0.342, Accuracy : 80.441%

# %% [markdown]
# #tensorboard
# #wandb https://pebpung.github.io/wandb/2021/10/06/WandB-1.html

# %%
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import numpy as np

fig, axes = plt.subplots(nrows=1, ncols = 2, figsize = (25, 10))

axes[0].plot(np.arange(len(train_acc_lst)), train_acc_lst, label = 'train_acc', linewidth=2)
axes[0].plot(np.arange(len(test_acc_lst)), test_acc_lst, label = 'test_acc', linewidth=2)
axes[0].set_title('Accuracy')
axes[0].legend(loc='best')

axes[1].plot(np.arange(len(train_loss_lst)), train_loss_lst, label = 'train_loss', linewidth=2)
axes[1].plot(np.arange(len(test_loss_lst)), test_loss_lst, label = 'test_loss', linewidth=2)
axes[1].set_title('Loss')
axes[1].legend(loc='best')
